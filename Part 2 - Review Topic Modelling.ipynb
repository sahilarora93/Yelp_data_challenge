# %% [markdown]
# # Purpose
#
# We want to build a tool for users to search for food businesses (restaurant, cafes) based on certain keywords such as ambience.
#
# * We aggregate all of the reviews for each restaurant and process them.
# * We remove stop words, tokenize the remaining words and also filter out infrequent words in order to get a collection of words that we think “describe” the restaurant.
# * We treat the aggregated review tokens for each restaurant as a document and input this list of documents to an Latent Semantic Indexing (LSI) model to identify categories.
# * The user input search query is the “example” document that need to be matched to the identified categories.
# * Based on the categories that user’s search query matches best with, it is clustered with restaurants with similar categories. We output the top 50 best matches of the model but also control for restaurants with poor ratings (<3.5).

# %% [markdown]
# # 0. Preparing the dataset

# %%
import json
import os
import ast
import pandas as pd

# %%
#importing the yelp businesses dataset
datastr=open('yelp_academic_dataset_business.json','r')
datajson=datastr.readlines()
check=[json.loads(x) for x in datajson]
ind=range(0,len(check))
business=pd.DataFrame(check,index=ind,columns=check[0].keys())

# %%
#importing the yelp reviews dataset
datastr=open('yelp_academic_dataset_review.json','r')
datajson=datastr.readlines()
check=[json.loads(x) for x in datajson]
ind=range(0,len(check))
reviews=pd.DataFrame(check,index=ind,columns=check[0].keys())

# %%
len(business[business['state']=='NY'])
# Out:
# 19

# %% [markdown]
# CHOOSE THE MOST FREQUENT OCCURENCES OF FOOD BUSINESS AND ONLY US STATES

# %%
#To see most frequent occurences of food categories to determine what to filter business dataset on
import collections as c
emptylist=[]
temp1=[emptylist.extend(x.split(', ')) for x in business['categories'] if pd.isnull(x)==False]
category_count=c.Counter(emptylist)
category_count.most_common(500)
# Out:
# [('Restaurants', 57173),
#  ('Shopping', 30231),
#  ('Food', 27118),
#  ('Beauty & Spas', 18967),
#  ('Home Services', 18634),
#  ('Health & Medical', 16157),
#  ('Local Services', 12906),
#  ('Automotive', 12656),
#  ('Nightlife', 12438),
#  ('Bars', 10853),
#  ('Event Planning & Services', 9774),
#  ('Active Life', 9119),
#  ('Fashion', 7406),
#  ('Coffee & Tea', 6936),
#  ('Sandwiches', 6912),
#  ('Hair Salons', 6825),
#  ('Fast Food', 6812),
#  ('American (Traditional)', 6659),
#  ('Pizza', 6603),
#  ('Home & Garden', 6020),
#  ('Auto Repair', 5877),
#  ('Hotels & Travel', 5808),
#  ('Arts & Entertainment', 5794),
#  ('Professional Services', 5620),
#  ('Doctors', 5450),
#  ('Real Estate', 5295),
#  ('Burgers', 5126),
#  ('Breakfast & Brunch', 5023),
#  ('Nail Salons', 4839),
#  ('Fitness & Instruction', 4559),
#  ('Italian', 4550),
#  ('Mexican', 4419),
#  ('Specialty Food', 4304),
#  ('Chinese', 4247),
#  ('American (New)', 4230),
#  ('Pets', 4001),
#  ('Hair Removal', 3766),
#  ('Bakeries', 3509),
#  ('Dentists', 3436),
#  ('Grocery', 3380),
#  ('Skin Care', 3230),
#  ('Cafes', 3056),
#  ('Education', 3033),
#  ('Desserts', 2991),
#  ('Financial Services', 2932),
#  ('Contractors', 2853),
#  ("Women's Clothing", 2817),
#  ('Pet Services', 2761),
#  ('General Dentistry', 2677),
#  ('Massage', 2617),
#  ('Ice Cream & Frozen Yogurt', 2613),
#  ('Hotels', 2575),
#  ('Japanese', 2566),
#  ('Chicken Wings', 2538),
#  ('Day Spas', 2529),
#  ('Seafood', 2369),
#  ('Salad', 2350),
#  ('Apartments', 2330),
#  ('Waxing', 2250),
#  ('Gyms', 2238),
#  ('Caterers', 2184),
#  ('Tires', 2173),
#  ('Sushi Bars', 2156),
#  ('Flowers & Gifts', 2058),
#  ('Sports Bars', 2055),
#  ('Venues & Event Spaces', 2055),
#  ('Oil Change Stations', 2054),
#  ('Accessories', 2034),
#  ('Sporting Goods', 2021),
#  ('Pubs', 2012),
#  ('Cosmetics & Beauty Supply', 1994),
#  ('Cosmetic Dentists', 1953),
#  ('Hair Stylists', 1939),
#  ('Barbers', 1932),
#  ('Car Dealers', 1922),
#  ('Auto Parts & Supplies', 1919),
#  ('Home Decor', 1906),
#  ('Beer', 1894),
#  ('Wine & Spirits', 1894),
#  ('Trainers', 1884),
#  ('Delis', 1835),
#  ('Furniture Stores', 1830),
#  ('Canadian (New)', 1828),
#  ('Asian Fusion', 1780),
#  ('Mediterranean', 1744),
#  ('Convenience Stores', 1742),
#  ('Eyelash Service', 1723),
#  ("Men's Clothing", 1717),
#  ('Barbeque', 1716),
#  ('Massage Therapy', 1713),
#  ('Jewelry', 1666),
#  ('Arts & Crafts', 1631),
#  ('Drugstores', 1616),
#  ('Medical Centers', 1597),
#  ('Department Stores', 1570),
#  ('Juice Bars & Smoothies', 1557),
#  ('Steakhouses', 1531),
#  ('Heating & Air Conditioning/HVAC', 1518),
#  ('Electronics', 1515),
#  ('Lounges', 1514),
#  ('Pet Groomers', 1493),
#  ('IT Services & Computer Repair', 1481),
#  ('Real Estate Services', 1475),
#  ('Gas Stations', 1461),
#  ('Specialty Schools', 1451),
#  ('Indian', 1417),
#  ('Thai', 1393),
#  ('Dry Cleaning & Laundry', 1370),
#  ('Laundry Services', 1368),
#  ('Shoe Stores', 1355),
#  ('Diners', 1351),
#  ('Chiropractors', 1322),
#  ('Books', 1281),
#  ('Mags', 1281),
#  ('Music & Video', 1281),
#  ('Plumbing', 1265),
#  ('Party & Event Planning', 1254),
#  ('Public Services & Government', 1251),
#  ('Banks & Credit Unions', 1241),
#  ('Veterinarians', 1240),
#  ('Pet Sitting', 1237),
#  ('Optometrists', 1230),
#  ('Vietnamese', 1225),
#  ('Real Estate Agents', 1212),
#  ('Body Shops', 1211),
#  ('Home Cleaning', 1205),
#  ('Makeup Artists', 1197),
#  ('Mobile Phones', 1194),
#  ('Middle Eastern', 1182),
#  ('Medical Spas', 1172),
#  ('Yoga', 1138),
#  ('Landscaping', 1120),
#  ('Pet Stores', 1116),
#  ('Cocktail Bars', 1115),
#  ('Car Wash', 1109),
#  ('Wine Bars', 1108),
#  ('Eyewear & Opticians', 1106),
#  ('Printing Services', 1097),
#  ('Florists', 1045),
#  ('Movers', 1030),
#  ('Auto Detailing', 1030),
#  ('Greek', 1023),
#  ('Vegetarian', 1017),
#  ('Photographers', 1013),
#  ('Transportation', 1006),
#  ('Performing Arts', 1004),
#  ('Hair Extensions', 996),
#  ('Lawyers', 995),
#  ('French', 977),
#  ('Self Storage', 971),
#  ('Physical Therapy', 961),
#  ('Sewing & Alterations', 958),
#  ('Music Venues', 948),
#  ('Property Management', 939),
#  ('Parks', 917),
#  ('Orthodontists', 909),
#  ('Tanning', 897),
#  ('Carpet Cleaning', 897),
#  ('Car Rental', 872),
#  ('Insurance', 869),
#  ('Ethnic Food', 862),
#  ('Discount Store', 858),
#  ('Kitchen & Bath', 851),
#  ('Korean', 847),
#  ('Flooring', 842),
#  ('Tobacco Shops', 839),
#  ('Buffets', 837),
#  ('Tattoo', 833),
#  ('Auto Glass Services', 831),
#  ('Local Flavor', 827),
#  ('Food Delivery Services', 826),
#  ('Building Supplies', 820),
#  ('Appliances', 809),
#  ('Food Trucks', 804),
#  ('Comfort Food', 793),
#  ('Gluten-Free', 787),
#  ('Soup', 778),
#  ('Appliances & Repair', 773),
#  ('Dance Clubs', 769),
#  ('Hardware Stores', 763),
#  ('Shipping Centers', 753),
#  ("Men's Hair Salons", 750),
#  ('Vegan', 741),
#  ('Wedding Planning', 736),
#  ('Mattresses', 723),
#  ('Donuts', 722),
#  ('Weight Loss Centers', 719),
#  ('Gift Shops', 718),
#  ('Hobby Shops', 718),
#  ('Acupuncture', 712),
#  ('Health Markets', 711),
#  ('Family Practice', 711),
#  ('Sports Wear', 708),
#  ('Art Galleries', 705),
#  ('Hot Dogs', 699),
#  ('Used', 697),
#  ('Vintage & Consignment', 697),
#  ('Tex-Mex', 695),
#  ('Child Care & Day Care', 695),
#  ('Oral Surgeons', 681),
#  ('Mobile Phone Repair', 667),
#  ('Preschools', 659),
#  ('Interior Design', 653),
#  ('Mortgage Brokers', 648),
#  ('Tours', 639),
#  ('Vape Shops', 634),
#  ('Blow Dry/Out Services', 627),
#  ('Thrift Stores', 618),
#  ('Laser Hair Removal', 618),
#  ('Nurseries & Gardening', 615),
#  ('Electronics Repair', 611),
#  ('Pool Cleaners', 610),
#  ('Caribbean', 604),
#  ('Towing', 599),
#  ('Session Photography', 597),
#  ('Pest Control', 596),
#  ('Pet Training', 585),
#  ('Pediatric Dentists', 583),
#  ('Bagels', 582),
#  ('Dive Bars', 580),
#  ('Bridal', 579),
#  ('Endodontists', 574),
#  ('Transmission Repair', 573),
#  ('Event Photography', 572),
#  ('Pool & Hot Tub Service', 560),
#  ('Toy Stores', 551),
#  ('Martial Arts', 551),
#  ('Halal', 549),
#  ('Latin American', 547),
#  ('Painters', 547),
#  ('Graphic Design', 546),
#  ('Golf', 540),
#  ('Nutritionists', 540),
#  ('Antiques', 537),
#  ('Bikes', 534),
#  ('Handyman', 526),
#  ('Computers', 520),
#  ('Photography Stores & Services', 515),
#  ('Religious Organizations', 513),
#  ('Gastropubs', 513),
#  ('Chicken Shop', 513),
#  ('Community Service/Non-Profit', 512),
#  ('Bookstores', 512),
#  ('Breweries', 508),
#  ("Children's Clothing", 501),
#  ('Office Cleaning', 500),
#  ('Southern', 493),
#  ('Meat Shops', 493),
#  ('Shopping Centers', 491),
#  ('Electricians', 487),
#  ('Notaries', 483),
#  ('Elementary Schools', 478),
#  ('Sports Clubs', 469),
#  ('Permanent Makeup', 468),
#  ('Reflexology', 462),
#  ('Naturopathic/Holistic', 462),
#  ('Diagnostic Services', 461),
#  ('Imported Food', 458),
#  ('Swimming Pools', 455),
#  ('Eyebrow Services', 451),
#  ('Auto Insurance', 447),
#  ('Damage Restoration', 446),
#  ('Periodontists', 441),
#  ('Tree Services', 438),
#  ('Cinema', 435),
#  ('Internet Service Providers', 434),
#  ('Marketing', 433),
#  ('Water Heater Installation/Repair', 433),
#  ('Chocolatiers & Shops', 430),
#  ('Urgent Care', 430),
#  ('Festivals', 429),
#  ('Tapas/Small Plates', 428),
#  ('Windshield Installation & Repair', 423),
#  ('Auto Customization', 421),
#  ('Personal Injury Law', 417),
#  ('Home & Rental Insurance', 416),
#  ('Tea Rooms', 415),
#  ('Obstetricians & Gynecologists', 415),
#  ('Hot Tub & Pool', 414),
#  ('Travel Services', 413),
#  ('Beer Bar', 412),
#  ('Noodles', 411),
#  ('Piercing', 407),
#  ('Security Systems', 405),
#  ('Casinos', 404),
#  ('Pakistani', 397),
#  ('Bubble Tea', 397),
#  ('Farmers Market', 395),
#  ('Windows Installation', 395),
#  ('Churches', 394),
#  ('Hospitals', 389),
#  ('Tax Services', 385),
#  ('Dry Cleaning', 385),
#  ('Carpeting', 385),
#  ('Limos', 383),
#  ('Musical Instruments & Teachers', 382),
#  ('Web Design', 381),
#  ('Cosmetic Surgeons', 380),
#  ('Boot Camps', 379),
#  ('Sports Medicine', 378),
#  ('Watches', 374),
#  ('Keys & Locksmiths', 373),
#  ('Mobile Phone Accessories', 372),
#  ('Party Supplies', 371),
#  ('Tapas Bars', 369),
#  ('Roofing', 368),
#  ('Fruits & Veggies', 368),
#  ('Counseling & Mental Health', 367),
#  ('Spray Tanning', 366),
#  ('Dance Studios', 366),
#  ('Masonry/Concrete', 357),
#  ('Ophthalmologists', 357),
#  ('Shades & Blinds', 356),
#  ('Pilates', 354),
#  ('Office Equipment', 353),
#  ('Internal Medicine', 353),
#  ('Arcades', 350),
#  ('Lighting Fixtures & Equipment', 347),
#  ('Pediatricians', 347),
#  ('Couriers & Delivery Services', 343),
#  ('Cupcakes', 335),
#  ('Amusement Parks', 334),
#  ('Outdoor Gear', 334),
#  ('Karaoke', 332),
#  ('Outlet Stores', 328),
#  ('Accountants', 326),
#  ('Adult Entertainment', 326),
#  ('Candy Stores', 323),
#  ('Art Supplies', 323),
#  ('Baby Gear & Furniture', 322),
#  ('Window Washing', 321),
#  ('Divorce & Family Law', 320),
#  ('Cards & Stationery', 320),
#  ('Museums', 319),
#  ('Home Inspectors', 319),
#  ('Garage Door Services', 319),
#  ('Airport Shuttles', 319),
#  ('Dog Walkers', 315),
#  ('Mailbox Centers', 314),
#  ('Fish & Chips', 313),
#  ('Used Car Dealers', 308),
#  ('Motorcycle Repair', 307),
#  ('Motorcycle Dealers', 305),
#  ('Smog Check Stations', 305),
#  ('Street Vendors', 304),
#  ('Recreation Centers', 304),
#  ('Hawaiian', 304),
#  ('Shoe Repair', 301),
#  ('Signmaking', 299),
#  ('Landscape Architects', 298),
#  ('Food Stands', 298),
#  ('Kids Activities', 298),
#  ('Wheel & Rim Repair', 298),
#  ('Jewelry Repair', 296),
#  ('Soul Food', 294),
#  ('Cabinetry', 291),
#  ('Criminal Defense Law', 291),
#  ('Music & DVDs', 290),
#  ('Irrigation', 289),
#  ('Formal Wear', 288),
#  ('Life Coach', 287),
#  ('Gardeners', 285),
#  ('Hookah Bars', 285),
#  ('Financial Advising', 285),
#  ('Wholesale Stores', 284),
#  ('Telecommunications', 284),
#  ('Videos & Video Game Rental', 282),
#  ('Dim Sum', 281),
#  ('Mass Media', 279),
#  ('Vitamins & Supplements', 278),
#  ('Tiling', 276),
#  ('Libraries', 276),
#  ('Dermatologists', 275),
#  ('Cajun/Creole', 274),
#  ('Reiki', 272),
#  ('Playgrounds', 271),
#  ('Door Sales/Installation', 269),
#  ('Orthopedists', 268),
#  ('Threading Services', 267),
#  ('Post Offices', 267),
#  ('Truck Rental', 266),
#  ('Guns & Ammo', 266),
#  ('Party Equipment Rentals', 263),
#  ('Bike Repair/Maintenance', 259),
#  ('Colleges & Universities', 257),
#  ('Junk Removal & Hauling', 256),
#  ('Custom Cakes', 254),
#  ('Rehabilitation Center', 254),
#  ('Lingerie', 253),
#  ('Taxis', 250),
#  ('Creperies', 247),
#  ('Pressure Washers', 246),
#  ('Summer Camps', 245),
#  ('Portuguese', 242),
#  ('Life Insurance', 241),
#  ('Leather Goods', 239),
#  ('Bike Rentals', 238),
#  ('Educational Services', 238),
#  ('Advertising', 233),
#  ('Pawn Shops', 229),
#  ('Tacos', 228),
#  ('Bowling', 227),
#  ('Middle Schools & High Schools', 227),
#  ('Car Stereo Installation', 226),
#  ('Home Health Care', 226),
#  ('Shaved Ice', 224),
#  ('Air Duct Cleaning', 224),
#  ('Landmarks & Historical Buildings', 221),
#  ('Diagnostic Imaging', 221),
#  ('Art Classes', 221),
#  ('Nail Technicians', 220),
#  ('Furniture Reupholstery', 219),
#  ('Interval Training Gyms', 219),
#  ('Filipino', 219),
#  ('Pet Boarding', 218),
#  ('Watch Repair', 218),
#  ('Lebanese', 218),
#  ('Boxing', 214),
#  ('Hiking', 209),
#  ('Ramen', 209),
#  ('Auto Loan Providers', 207),
#  ('Video/Film Production', 207),
#  ('Butcher', 207),
#  ('Legal Services', 207),
#  ('Fabric Stores', 206),
#  ('Pool Halls', 206),
#  ('DUI Law', 204),
#  ('Organic Stores', 204),
#  ('Modern European', 204),
#  ('Glass & Mirrors', 203),
#  ('Taiwanese', 203),
#  ('Traditional Chinese Medicine', 203),
#  ('Home Window Tinting', 203),
#  ('Laser Eye Surgery/Lasik', 202),
#  ('Seafood Markets', 201),
#  ('Employment Agencies', 200),
#  ('Bed & Breakfast', 199),
#  ('Dance Schools', 199),
#  ('Cheesesteaks', 198),
#  ('Commercial Real Estate', 198),
#  ('Pharmacy', 198),
#  ('Pain Management', 196),
#  ('Irish', 195),
#  ('Drywall Installation & Repair', 195),
#  ('Home Organization', 193),
#  ('Television Service Providers', 193),
#  ('Public Transportation', 193),
#  ('Musical Instrument Services', 192),
#  ('DJs', 191),
#  ('Water Purification Services', 191),
#  ('Car Window Tinting', 189),
#  ('Resorts', 188),
#  ('Comic Books', 188),
#  ('Check Cashing/Pay-day Loans', 186),
#  ('Cheese Shops', 183),
#  ('Spanish', 181),
#  ('Refinishing Services', 179),
#  ('Screen Printing/T-Shirt Printing', 177),
#  ('Funeral Services & Cemeteries', 177),
#  ('Persian/Iranian', 176),
#  ('Home Theatre Installation', 174),
#  ('Bankruptcy Law', 174),
#  ('Fences & Gates', 174),
#  ('Estate Planning Law', 173),
#  ('Carpet Installation', 172),
#  ('Social Clubs', 172),
#  ('Amateur Sports Teams', 171),
#  ('Podiatrists', 171),
#  ('Poutineries', 170),
#  ('Patisserie/Cake Shop', 170),
#  ('Stadiums & Arenas', 169),
#  ('Medical Supplies', 168),
#  ('Escape Games', 168),
#  ('Wineries', 168),
#  ('Laboratory Testing', 168),
#  ('Gay Bars', 167),
#  ('Investing', 167),
#  ('Gold Buyers', 167),
#  ('Food Court', 167),
#  ('General Litigation', 166),
#  ('Do-It-Yourself Food', 166),
#  ('Plus Size Fashion', 165),
#  ('Videographers', 165),
#  ('Coffee Roasteries', 164),
#  ('Packing Services', 164),
#  ('Data Recovery', 163),
#  ('Head Shops', 161),
#  ('Barre Classes', 161),
#  ('Cannabis Clinics', 159),
#  ('German', 158),
#  ('Airports', 158),
#  ('Internet Cafes', 156),
#  ('Personal Shopping', 155),
#  ('Art Schools', 154),
#  ('Solar Installation', 154),
#  ('Cosmetology Schools', 154),
#  ('Parking', 153),
#  ('Framing', 152),
#  ('Retirement Homes', 151),
#  ('Supernatural Readings', 150)]

# %%
#defining functions to filter
def category_filter(category):
    foodstuff=('Restaurants','Food','Nightlife', 'Bars', 'Fast Food', 'Sandwiches', 
               'Coffee & Tea', 'American (Traditional)', 'Pizza', 'Breakfast & Brunch', 
               'Bakeries', 'Burgers', 'Italian', 'Mexican', 'Chinese', 'American (New)', 
               'Cafes', 'Ice Cream & Frozen Yogurt', 'Food Trucks', 'Desserts', 'Seafood', 
               'Salad', 'Sushi Bars', 'Delis', 'Juice Bars & Smoothies', 'Steakhouses')
    if pd.isnull(category['categories']) == False:
        temp=category['categories'].split(', ')
        checksum=sum([foodstuff.count(x) for x in temp])
        return checksum
    else:
        return 0
    
def cleanstate(input_state):
    import numpy as np
    state_list = ('AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI','ID','IL',
                  'IN','IA','KS','KY','LA','ME','MD','MA','MI','MN','MS','MO','MT',
                  'NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','RI',
                  'SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY')
    if input_state not in state_list:
        return np.NaN
    return input_state

# %%
#filtering for only restaurants and only US states
business['restaurant_flag']=business.apply(category_filter,axis=1)
business['state'] = business['state'].apply(cleanstate)
filtered=business[business['restaurant_flag']>0]
filtered=filtered[filtered['state'].notnull()]
len(filtered)*100/len(business)
# Out:
# 24.943661747784912

# %% [markdown]
# CREATE RESTAURANT REVIEWS

# %%
restaurant_reviews=reviews[reviews["business_id"].isin(filtered["business_id"])]

# %%
#basic descriptions
#restaurant_reviews[restaurant_reviews['user_id']=='msQe1u7Z_XuqjGoqhB0J5g']
print(len(restaurant_reviews))
print(len(restaurant_reviews['business_id'].unique()))
print(len(restaurant_reviews['user_id'].unique()))
# Out:
# 3365595
# 47042
# 951201

# %%
#desired fields
user_rating_count=restaurant_reviews[['user_id','business_id']].groupby(['user_id']).count()
user_rating_count=user_rating_count.rename(columns = {'business_id':'user_rating_count'})
average_rating_restaurant=restaurant_reviews[['business_id','stars']].groupby(['business_id']).mean()
average_rating_restaurant=average_rating_restaurant.rename(columns = {'stars':'average_rating_rest'})
count_rating_restaurant=restaurant_reviews[['business_id','stars']].groupby(['business_id']).count()
count_rating_restaurant=count_rating_restaurant.rename(columns = {'stars':'rest_review_count'})

# %%
#merging desired columns back to main reviews dataset
restaurant_reviews=restaurant_reviews.merge(user_rating_count,how='left',on='user_id')
restaurant_reviews=restaurant_reviews.merge(average_rating_restaurant,how='left',on=['business_id'])
restaurant_reviews=restaurant_reviews.merge(count_rating_restaurant,how='left',on=['business_id'])

# %% [markdown]
# # 1. Set Up

# %% [markdown]
# ### Import libraries and load dataset

# %%
#selecting only desired columns
business_details = filtered[['business_id','name','stars','review_count']]
documents = restaurant_reviews[['business_id','text']]

# %%
#Must aggregate reviews for each restaurant
import collections as c
only_rests=set(rest_reviews['business_id'])
final_output=c.defaultdict()

def lolwut(df):
    for i in only_rests:
        emptylist=''
        temp=df[df['business_id']==i]
        for j in range(len(temp)):
            emptylist+=(temp['text'].iloc[j])+'\n'
        final_output[i]=emptylist
    return final_output

aggregated_reviews=lolwut(documents)

# %%
#converting dict to dataframe for easier manipulation
reviews=pd.DataFrame()
reviews['business_id']=list(aggregated_reviews)
reviews['text']=list(aggregated_reviews.values())

# %%
#Merging business names and stars with the review dataset
import pandas as pd
reviews=reviews.merge(business_details,how='left',on='business_id')
reviews.head()
# Out:
#               business_id                                               text  \
# 0  OH3baEaklANPe1farAKgRg  Why 4 stars? It's McDonalds, that's why. Its c...
# 1  UdEmYOnk2iJDY9lpEPAlJQ  I've never had a bad experience at this place,...
# 2  iAD5r5vNOzc1AP6UA5yFiQ  This place has a serious problem with unwelcom...
# 3  dNDAdeE8olF4eZaslNtBZw  Sister in town from Ontario Canada and wanted ...
# 4  j-6MgWWlotFZAQ23LZrTPQ  I've been eying the Trattoria since it opened,...
#
#                                name  stars  review_count
# 0                        McDonald's    2.0            28
# 1         Floridino's Pizza & Pasta    4.0           420
# 2                      Bella Fresco    4.0           131
# 3        Manny's Mexican Restaurant    2.5           127
# 4  Queen Creek Olive Mill Trattoria    3.5            24

# %%
len(reviews)
# Out:
# 24386

# %% [markdown]
# # 2. Cleaning reviews

# %%
#cleaning reviews and removing stop words to be input in the model
#Trying to use LDA to model topics for reviews
from gensim import corpora
from gensim.models.ldamodel import LdaModel
from gensim.parsing.preprocessing import STOPWORDS
import pprint
documents=reviews['text'] #need only the text
stoplist = list(STOPWORDS)
texts = [[word for word in document.lower().split() if (word not in stoplist) & (word.isalnum())]
         for document in documents if isinstance(document,str)] #tokenizing

# %%
len(texts) #checking to see if same length
# Out:
# 24386

# %%
#In the above code, we tokenize all of the reviews and remove stop words
#remove words that appear only once 
#frequency of the token across ALL reviews

#counting the frequency of token across ALL reviews
from collections import defaultdict
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1
        
#removing tokens that occur only once across all reviews
texts = [[token for token in text if frequency[token] > 10] for text in texts] #if frequence(token)>1

# %%
dictionary = corpora.Dictionary(texts) #word id-word pairs
corpus = [dictionary.doc2bow(text) for text in texts] #word id-frequence of word pairs

# %%
#Checking frequency of the 'contextual' words we would like to identify

import collections as c
emptylist=[]
[emptylist.extend(x) for x in texts]
len(emptylist)
count=c.Counter(emptylist)
count['candle']
# Out:
# 93

# %% [markdown]
# # 3. LDA and LSI Model

# %%
#Set parameters
num_topics = 100 #can experiment with this, for the number of reviews we have, more topics==contextual words!
passes = 20
lda = LdaModel(corpus,
              id2word=dictionary,
              num_topics=num_topics,
              passes=passes)

lda.print_topics()
# Out:
# /Users/sanjanarosario/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1023: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)
# [(19,
#   '0.028*"sure" + 0.027*"dinner" + 0.025*"pretty" + 0.025*"table" + 0.024*"server" + 0.021*"food" + 0.020*"seated" + 0.017*"ended" + 0.015*"experience" + 0.015*"especially"'),
#  (47,
#   '0.348*"hot" + 0.087*"chili" + 0.055*"dog" + 0.036*"decent" + 0.028*"visits" + 0.023*"break" + 0.020*"larger" + 0.020*"sold" + 0.017*"written" + 0.016*"beautifully"'),
#  (89,
#   '0.115*"fish" + 0.090*"clean" + 0.071*"cheap" + 0.053*"place" + 0.037*"lunch" + 0.032*"expect" + 0.031*"nice" + 0.030*"size" + 0.030*"coconut" + 0.026*"great"'),
#  (82,
#   '0.075*"staff" + 0.063*"great" + 0.050*"friendly" + 0.048*"food" + 0.038*"restaurant" + 0.030*"place" + 0.025*"helpful" + 0.024*"visit" + 0.022*"visiting" + 0.022*"owners"'),
#  (64,
#   '0.183*"open" + 0.073*"expensive" + 0.062*"days" + 0.052*"weeks" + 0.050*"ago" + 0.047*"comfortable" + 0.046*"hungry" + 0.038*"job" + 0.037*"casual" + 0.035*"cozy"'),
#  (79,
#   '0.071*"minutes" + 0.034*"time" + 0.033*"order" + 0.031*"food" + 0.030*"waited" + 0.027*"service" + 0.025*"10" + 0.024*"wait" + 0.020*"20" + 0.017*"took"'),
#  (53,
#   '0.111*"spicy" + 0.070*"curry" + 0.065*"indian" + 0.040*"die" + 0.039*"spice" + 0.035*"dish" + 0.032*"venue" + 0.030*"food" + 0.026*"flavors" + 0.020*"dishes"'),
#  (90,
#   '0.038*"times" + 0.038*"bigger" + 0.032*"mix" + 0.028*"years" + 0.026*"going" + 0.025*"like" + 0.025*"big" + 0.022*"incredible" + 0.021*"better" + 0.021*"tried"'),
#  (2,
#   '0.071*"like" + 0.054*"eaten" + 0.051*"inside" + 0.043*"tasted" + 0.040*"place" + 0.039*"taste" + 0.035*"better" + 0.029*"dip" + 0.027*"consistently" + 0.026*"love"'),
#  (9,
#   '0.065*"variety" + 0.060*"place" + 0.059*"pretty" + 0.050*"good" + 0.034*"limited" + 0.032*"tables" + 0.028*"people" + 0.026*"menu" + 0.026*"appreciate" + 0.023*"looks"'),
#  (21,
#   '0.208*"chicken" + 0.040*"food" + 0.037*"ordered" + 0.029*"fried" + 0.020*"rice" + 0.018*"got" + 0.017*"sauce" + 0.017*"like" + 0.017*"time" + 0.015*"lunch"'),
#  (41,
#   '0.118*"owner" + 0.041*"box" + 0.036*"going" + 0.035*"location" + 0.035*"city" + 0.028*"paid" + 0.025*"normal" + 0.025*"tempe" + 0.023*"new" + 0.022*"wednesday"'),
#  (87,
#   '0.064*"place" + 0.053*"yelp" + 0.046*"gets" + 0.024*"reviews" + 0.022*"surprisingly" + 0.021*"typical" + 0.019*"strawberry" + 0.019*"pretty" + 0.018*"chill" + 0.018*"complaints"'),
#  (6,
#   '0.313*"pizza" + 0.039*"crust" + 0.036*"place" + 0.028*"cheese" + 0.027*"good" + 0.027*"like" + 0.022*"ordered" + 0.020*"sauce" + 0.020*"best" + 0.017*"tomato"'),
#  (46,
#   '0.283*"happy" + 0.199*"hour" + 0.044*"great" + 0.027*"day" + 0.020*"appetizers" + 0.019*"outstanding" + 0.018*"drinks" + 0.018*"previous" + 0.018*"soda" + 0.013*"cold"'),
#  (70,
#   '0.063*"reason" + 0.044*"start" + 0.028*"let" + 0.026*"restaurant" + 0.025*"stars" + 0.018*"know" + 0.017*"allow" + 0.016*"hours" + 0.015*"damn" + 0.015*"team"'),
#  (61,
#   '0.069*"bacon" + 0.066*"counter" + 0.052*"thanks" + 0.048*"pepper" + 0.048*"salt" + 0.041*"morning" + 0.039*"dogs" + 0.037*"order" + 0.032*"ones" + 0.030*"style"'),
#  (8,
#   '0.135*"italian" + 0.038*"stuffed" + 0.033*"cute" + 0.031*"pasta" + 0.023*"product" + 0.020*"cleveland" + 0.020*"tons" + 0.019*"peppers" + 0.019*"try" + 0.019*"good"'),
#  (54,
#   '0.040*"believe" + 0.036*"filling" + 0.033*"yes" + 0.032*"bought" + 0.031*"recently" + 0.030*"cash" + 0.030*"simple" + 0.024*"boy" + 0.024*"complain" + 0.023*"american"'),
#  (56,
#   '0.175*"excellent" + 0.093*"great" + 0.084*"wonderful" + 0.074*"food" + 0.067*"service" + 0.043*"thank" + 0.043*"glad" + 0.029*"dim" + 0.024*"waffles" + 0.023*"plan"')]

# %%
#after multiple attempts, trying LSI model, instead of LDA

from gensim.similarities.docsim import Similarity
from gensim import corpora, models, similarities
lsi = models.LsiModel(corpus, id2word=dictionary, num_topics=100)

doc=input('What are you searching for today?')
vec_bow = dictionary.doc2bow(doc.lower().split())
vec_lsi = lsi[vec_bow]
index = similarities.MatrixSimilarity(lsi[corpus])
sims = index[vec_lsi]
sims = sorted(enumerate(sims), key=lambda item: -item[1])
sims[0][0]

indices=[sims[i][0] for i in range(50) if (reviews['stars'].iloc[sims[i][0]]>=3.5)]
reviews[['name','stars','text']].iloc[indices]
# Out:
# What are you searching for today?nice ambiance crowded
# /Users/sanjanarosario/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
#                                    name  stars  \
# 7896                             Subway    5.0
# 7222                        Kung Fu Tea    4.0
# 6881             Harley's Liquor & Bait    4.5
# 20122             George's Italian Deli    4.5
# 19300       Giant Eagle Market District    4.0
# 7994             Panini Bread and Grill    5.0
# 23358                      Trader Joe's    4.0
# 16981               Putters Bar & Grill    4.0
# 5443                 Thunderbird Lounge    3.5
# 7235                               Aldi    4.0
# 6403                             Subway    3.5
# 19109                           Smith's    3.5
# 12424                        Cafe Zinho    4.0
# 16586           KiwiSpoon Frozen Yogurt    4.0
# 3342             The Lion's Tail Tavern    4.5
# 18735                          Eba Cafe    4.5
# 2175           Macayo's Mexican Kitchen    3.5
# 13156   H2 Huth & Harris Wine Merchants    4.5
# 23416                         Starbucks    3.5
# 11073  Crown Station Coffee House & Pub    4.0
# 14395                        Albertsons    3.5
# 4862               Tip Top Daily Market    5.0
# 11206                         Nutrishop    4.5
# 5814                  Yummy Grill Sushi    3.5
# 3779                        Mr. Torta's    3.5
# 8351                              Bar 1    4.0
# 7621                             Target    3.5
# 21687       Davis Bakery & Delicatessen    4.0
# 1245                          Maui Wowi    4.0
# 1532                        Jamba Juice    3.5
# 17288                          Scullery    3.5
# 6760                        Albertson's    3.5
# 4214                     Juice Box Cafe    4.0
# 19048              Green Valley Grocery    3.5
# 6864                       Shale's Cafe    4.0
# 19493                 Metcalfe's Market    4.0
# 21191  Sweet Frog Premium Frozen Yogurt    4.5
# 14425                     Smoothie King    4.5
#
#                                                     text
# 7896   Employees are always super nice and efficient....
# 7222   Nice little shop .  Had quite a variety. the k...
# 6881   Nice people, not a bad selection, and close to...
# 20122  The George is the best. The ladies and the own...
# 19300  Without a doubt, Giant Eagle has nailed it wit...
# 7994   It is so nice to have a neighborhood soup , sa...
# 23358  Fantastic place.  A nice change of pace from y...
# 16981  The lady's were very nice behind the bar!  I k...
# 5443   Great cocktails ! Nice atmosphere, very nice m...
# 7235   Cheap wine! Cheap fruit! Cheap everything! And...
# 6403   I've been here twice and both times the girls ...
# 19109  This store in particular has  an amazing custo...
# 12424  Nice. No really, nice! A shade expensive but n...
# 16586  A surprisingly tasty dessert! I'm an original ...
# 3342   As far as a gaming bar goes, this is a nice sp...
# 18735  eba is good . \n\nold location was much better...
# 2175   Decided to go here instead of the other Macayo...
# 13156  Nice place, right off the square in Medina, wh...
# 23416  good- in californa there is a starbucks on eve...
# 11073  As with anywhere, there are nice people, and t...
# 14395  Nice place. A lot of fruit options, which I li...
# 4862   Love  tiptop people are great good selection o...
# 11206  Super nice guys. Hooked me up with all kinds o...
# 5814   The atmosphere was really nice but I was not t...
# 3779   A nice addition to the area. Their meat is wha...
# 8351   Nice bar but they need to rotate the music vid...
# 7621   Love Super Target. Didn't even know it existed...
# 21687  Awesome breakfast. Quick service. Never crowde...
# 1245   Nice place. Had a blackberry lava beach smooth...
# 1532   Yesterday As I was leaving my house with my mo...
# 17288  cute lil place... the chef made us a beautiful...
# 6760   This store is really nice inside and the staff...
# 4214   Tasty wraps and salads.   Nice little place.  ...
# 19048  Super nice people who work here.  Really cool,...
# 6864   When I walked in and saw Jim Parey I thought I...
# 19493  This is my favorite lunch or break spot on far...
# 21191  I enjoyed this place, they have a good variety...
# 14425  I love this place. It is so nice to have a gre...
